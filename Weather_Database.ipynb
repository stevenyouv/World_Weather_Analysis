# %%
import numpy as np 
from citipy import citipy
import gmaps
import requests
import pandas as pd 
from datetime import datetime

from config import weather_api_key
from config import g_key

# %%
#3. Create a new set of 2000 random latitudes and longitudes.
lats = np.random.uniform(-90.0,90.0, size=2000)
lngs = np.random.uniform(-180.0,180.0,size=2000)
lats_lngs = zip(lats, lngs)
coordinates = list(lats_lngs)

# %%
#4.  Get the nearest city usig the citipymodule.
cities = list()
for coord in coordinates:
    cities_name = citipy.nearest_city(coord[0],coord[1]).city_name
    if cities_name not in cities:
        cities.append(cities_name)
print(cities[:10], 'Generate', len(cities))
# Out:
# ['powell', 'ayotzintepec', 'bredasdorp', 'bluff', 'saint-philippe', 'hami', 'lagoa', 'esperance', 'champerico', 'beloha'] Generate 757

# %%
#5.  Perform an API Call with the OpenWeatherMap.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=2b62b03a45a8bb9adbbb80a14d5ee788

# %%
#6. Retrieve information from the API Call
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city and ensure imperial data is requested
    city_url = url + "&q=" + city + '&units=imperial'

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        
             
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_weather_desc})
        
        # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | powell
# Processing Record 2 of Set 1 | ayotzintepec
# Processing Record 3 of Set 1 | bredasdorp
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | saint-philippe
# Processing Record 6 of Set 1 | hami
# Processing Record 7 of Set 1 | lagoa
# Processing Record 8 of Set 1 | esperance
# Processing Record 9 of Set 1 | champerico
# Processing Record 10 of Set 1 | beloha
# Processing Record 11 of Set 1 | samarai
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | vila franca do campo
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | fonte boa
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | andapa
# Processing Record 18 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 19 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 20 of Set 1 | salalah
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | atuona
# Processing Record 23 of Set 1 | new norfolk
# Processing Record 24 of Set 1 | kapaa
# Processing Record 25 of Set 1 | kruisfontein
# Processing Record 26 of Set 1 | castro
# Processing Record 27 of Set 1 | narasannapeta
# Processing Record 28 of Set 1 | umm lajj
# Processing Record 29 of Set 1 | buchanan
# Processing Record 30 of Set 1 | marblehead
# Processing Record 31 of Set 1 | dogondoutchi
# Processing Record 32 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 33 of Set 1 | carnarvon
# Processing Record 34 of Set 1 | magdagachi
# Processing Record 35 of Set 1 | chukhloma
# Processing Record 36 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 37 of Set 1 | geraldton
# Processing Record 38 of Set 1 | port alfred
# Processing Record 39 of Set 1 | buin
# Processing Record 40 of Set 1 | camacupa
# Processing Record 41 of Set 1 | maceio
# Processing Record 42 of Set 1 | nago
# Processing Record 43 of Set 1 | thompson
# Processing Record 44 of Set 1 | khatanga
# Processing Record 45 of Set 1 | aklavik
# Processing Record 46 of Set 1 | ushuaia
# Processing Record 47 of Set 1 | omsukchan
# Processing Record 48 of Set 1 | finnsnes
# Processing Record 49 of Set 1 | vaini
# Processing Record 50 of Set 1 | san ignacio
# Processing Record 1 of Set 2 | kurchum
# Processing Record 2 of Set 2 | tiksi
# Processing Record 3 of Set 2 | scalea
# Processing Record 4 of Set 2 | komsomolskiy
# Processing Record 5 of Set 2 | tuatapere
# Processing Record 6 of Set 2 | tarboro
# Processing Record 7 of Set 2 | tura
# Processing Record 8 of Set 2 | jamestown
# Processing Record 9 of Set 2 | avarua
# Processing Record 10 of Set 2 | tommot
# Processing Record 11 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 12 of Set 2 | sola
# Processing Record 13 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 14 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 15 of Set 2 | ngunguru
# Processing Record 16 of Set 2 | mataura
# Processing Record 17 of Set 2 | tasiilaq
# Processing Record 18 of Set 2 | kande
# Processing Record 19 of Set 2 | praia da vitoria
# Processing Record 20 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 21 of Set 2 | norman wells
# Processing Record 22 of Set 2 | iqaluit
# Processing Record 23 of Set 2 | alghero
# Processing Record 24 of Set 2 | qaanaaq
# Processing Record 25 of Set 2 | upernavik
# Processing Record 26 of Set 2 | deputatskiy
# Processing Record 27 of Set 2 | saskylakh
# Processing Record 28 of Set 2 | cape town
# Processing Record 29 of Set 2 | vestmannaeyjar
# Processing Record 30 of Set 2 | eldikan
# City not found. Skipping...
# Processing Record 31 of Set 2 | edson
# Processing Record 32 of Set 2 | kutum
# Processing Record 33 of Set 2 | vaitape
# Processing Record 34 of Set 2 | hualmay
# Processing Record 35 of Set 2 | chokurdakh
# Processing Record 36 of Set 2 | santander
# Processing Record 37 of Set 2 | bethel
# Processing Record 38 of Set 2 | isangel
# Processing Record 39 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 40 of Set 2 | berlevag
# Processing Record 41 of Set 2 | roma
# Processing Record 42 of Set 2 | great falls
# Processing Record 43 of Set 2 | banjarmasin
# Processing Record 44 of Set 2 | sorland
# Processing Record 45 of Set 2 | dunda
# Processing Record 46 of Set 2 | torbay
# Processing Record 47 of Set 2 | clyde river
# Processing Record 48 of Set 2 | ardakan
# Processing Record 49 of Set 2 | bone
# Processing Record 50 of Set 2 | sao filipe
# Processing Record 1 of Set 3 | ekhabi
# Processing Record 2 of Set 3 | wilmington
# Processing Record 3 of Set 3 | copperas cove
# Processing Record 4 of Set 3 | asau
# Processing Record 5 of Set 3 | cherskiy
# Processing Record 6 of Set 3 | dingle
# Processing Record 7 of Set 3 | victoria
# Processing Record 8 of Set 3 | inhambane
# Processing Record 9 of Set 3 | lorengau
# Processing Record 10 of Set 3 | acarau
# Processing Record 11 of Set 3 | yellowknife
# Processing Record 12 of Set 3 | lavrentiya
# Processing Record 13 of Set 3 | vardo
# Processing Record 14 of Set 3 | kosh-agach
# Processing Record 15 of Set 3 | port blair
# Processing Record 16 of Set 3 | juneau
# Processing Record 17 of Set 3 | yeppoon
# Processing Record 18 of Set 3 | mbandaka
# Processing Record 19 of Set 3 | coihaique
# Processing Record 20 of Set 3 | lebu
# Processing Record 21 of Set 3 | hobart
# Processing Record 22 of Set 3 | san quintin
# Processing Record 23 of Set 3 | fortuna
# Processing Record 24 of Set 3 | talnakh
# Processing Record 25 of Set 3 | soubre
# Processing Record 26 of Set 3 | ust-shonosha
# Processing Record 27 of Set 3 | dubbo
# Processing Record 28 of Set 3 | slonim
# Processing Record 29 of Set 3 | puerto del rosario
# Processing Record 30 of Set 3 | kodiak
# Processing Record 31 of Set 3 | port elizabeth
# Processing Record 32 of Set 3 | dikson
# Processing Record 33 of Set 3 | los llanos de aridane
# Processing Record 34 of Set 3 | sinkat
# City not found. Skipping...
# Processing Record 35 of Set 3 | kenai
# Processing Record 36 of Set 3 | qaqortoq
# Processing Record 37 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 38 of Set 3 | oktyabrskiy
# Processing Record 39 of Set 3 | barrow
# Processing Record 40 of Set 3 | karaj
# Processing Record 41 of Set 3 | san jose
# Processing Record 42 of Set 3 | ancud
# Processing Record 43 of Set 3 | ahipara
# Processing Record 44 of Set 3 | chuy
# Processing Record 45 of Set 3 | galveston
# Processing Record 46 of Set 3 | bid
# City not found. Skipping...
# Processing Record 47 of Set 3 | margate
# Processing Record 48 of Set 3 | waingapu
# Processing Record 49 of Set 3 | nanortalik
# Processing Record 50 of Set 3 | georgetown
# Processing Record 1 of Set 4 | olafsvik
# Processing Record 2 of Set 4 | qinhuangdao
# Processing Record 3 of Set 4 | inuvik
# Processing Record 4 of Set 4 | arraial do cabo
# Processing Record 5 of Set 4 | coquimbo
# Processing Record 6 of Set 4 | soe
# Processing Record 7 of Set 4 | hermanus
# Processing Record 8 of Set 4 | nantucket
# Processing Record 9 of Set 4 | cidreira
# Processing Record 10 of Set 4 | nikolskoye
# Processing Record 11 of Set 4 | sainte-maxime
# Processing Record 12 of Set 4 | ulladulla
# Processing Record 13 of Set 4 | cap malheureux
# Processing Record 14 of Set 4 | vung tau
# Processing Record 15 of Set 4 | codrington
# Processing Record 16 of Set 4 | vila velha
# Processing Record 17 of Set 4 | faya
# Processing Record 18 of Set 4 | nizhniy kuranakh
# Processing Record 19 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 4 | mar del plata
# Processing Record 21 of Set 4 | otane
# Processing Record 22 of Set 4 | biak
# Processing Record 23 of Set 4 | kavieng
# Processing Record 24 of Set 4 | ritchie
# Processing Record 25 of Set 4 | ponta do sol
# Processing Record 26 of Set 4 | narsaq
# Processing Record 27 of Set 4 | sibut
# Processing Record 28 of Set 4 | suoyarvi
# Processing Record 29 of Set 4 | hamilton
# Processing Record 30 of Set 4 | ust-ishim
# Processing Record 31 of Set 4 | portland
# Processing Record 32 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 33 of Set 4 | kisangani
# Processing Record 34 of Set 4 | bilibino
# Processing Record 35 of Set 4 | visby
# Processing Record 36 of Set 4 | safwah
# City not found. Skipping...
# Processing Record 37 of Set 4 | weligama
# Processing Record 38 of Set 4 | tomatlan
# Processing Record 39 of Set 4 | ribeira grande
# Processing Record 40 of Set 4 | longido
# Processing Record 41 of Set 4 | cockburn town
# Processing Record 42 of Set 4 | wuwei
# Processing Record 43 of Set 4 | ulaangom
# Processing Record 44 of Set 4 | mount gambier
# Processing Record 45 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 46 of Set 4 | bairiki
# Processing Record 47 of Set 4 | saint-joseph
# Processing Record 48 of Set 4 | loandjili
# Processing Record 49 of Set 4 | bambous virieux
# Processing Record 50 of Set 4 | mayo
# Processing Record 1 of Set 5 | taoudenni
# Processing Record 2 of Set 5 | rassvet
# Processing Record 3 of Set 5 | tuktoyaktuk
# Processing Record 4 of Set 5 | acaponeta
# Processing Record 5 of Set 5 | savannah bight
# Processing Record 6 of Set 5 | aban
# Processing Record 7 of Set 5 | qianan
# Processing Record 8 of Set 5 | longyearbyen
# Processing Record 9 of Set 5 | hasaki
# Processing Record 10 of Set 5 | pangnirtung
# Processing Record 11 of Set 5 | ikom
# Processing Record 12 of Set 5 | tshikapa
# Processing Record 13 of Set 5 | tongliao
# Processing Record 14 of Set 5 | provideniya
# Processing Record 15 of Set 5 | puerto ayora
# Processing Record 16 of Set 5 | east london
# Processing Record 17 of Set 5 | hilo
# Processing Record 18 of Set 5 | lykhivka
# Processing Record 19 of Set 5 | beaverlodge
# Processing Record 20 of Set 5 | merauke
# Processing Record 21 of Set 5 | yakeshi
# Processing Record 22 of Set 5 | husavik
# Processing Record 23 of Set 5 | katangli
# Processing Record 24 of Set 5 | quatre cocos
# Processing Record 25 of Set 5 | hokitika
# Processing Record 26 of Set 5 | miquelon
# Processing Record 27 of Set 5 | broome
# Processing Record 28 of Set 5 | poum
# Processing Record 29 of Set 5 | ayer itam
# City not found. Skipping...
# Processing Record 30 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 31 of Set 5 | tramore
# Processing Record 32 of Set 5 | ljaskovec
# City not found. Skipping...
# Processing Record 33 of Set 5 | mantua
# Processing Record 34 of Set 5 | mahebourg
# Processing Record 35 of Set 5 | fairbanks
# Processing Record 36 of Set 5 | mehamn
# Processing Record 37 of Set 5 | tobermory
# Processing Record 38 of Set 5 | zhigansk
# Processing Record 39 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 40 of Set 5 | la ronge
# Processing Record 41 of Set 5 | goderich
# Processing Record 42 of Set 5 | oyama
# Processing Record 43 of Set 5 | rabo de peixe
# Processing Record 44 of Set 5 | christchurch
# Processing Record 45 of Set 5 | karratha
# Processing Record 46 of Set 5 | noumea
# Processing Record 47 of Set 5 | port lincoln
# Processing Record 48 of Set 5 | adrar
# Processing Record 49 of Set 5 | leningradskiy
# Processing Record 50 of Set 5 | airai
# Processing Record 1 of Set 6 | parintins
# Processing Record 2 of Set 6 | ixtapa
# Processing Record 3 of Set 6 | alotau
# City not found. Skipping...
# Processing Record 4 of Set 6 | novi pazar
# Processing Record 5 of Set 6 | kirakira
# Processing Record 6 of Set 6 | kavaratti
# Processing Record 7 of Set 6 | sibu
# Processing Record 8 of Set 6 | manggar
# Processing Record 9 of Set 6 | tubruq
# City not found. Skipping...
# Processing Record 10 of Set 6 | flin flon
# Processing Record 11 of Set 6 | bengkulu
# Processing Record 12 of Set 6 | macau
# Processing Record 13 of Set 6 | dudinka
# Processing Record 14 of Set 6 | anadyr
# Processing Record 15 of Set 6 | haapiti
# Processing Record 16 of Set 6 | tahlequah
# Processing Record 17 of Set 6 | shingu
# Processing Record 18 of Set 6 | caravelas
# Processing Record 19 of Set 6 | dahra
# Processing Record 20 of Set 6 | mackenzie
# Processing Record 21 of Set 6 | ostrovnoy
# Processing Record 22 of Set 6 | kahului
# Processing Record 23 of Set 6 | north myrtle beach
# Processing Record 24 of Set 6 | uyutne
# Processing Record 25 of Set 6 | bandarbeyla
# Processing Record 26 of Set 6 | vanimo
# Processing Record 27 of Set 6 | namatanai
# Processing Record 28 of Set 6 | kyra
# Processing Record 29 of Set 6 | alexandria
# Processing Record 30 of Set 6 | boromo
# Processing Record 31 of Set 6 | meulaboh
# Processing Record 32 of Set 6 | nam tha
# City not found. Skipping...
# Processing Record 33 of Set 6 | avera
# Processing Record 34 of Set 6 | cadillac
# Processing Record 35 of Set 6 | bosaso
# Processing Record 36 of Set 6 | aykhal
# Processing Record 37 of Set 6 | lompoc
# Processing Record 38 of Set 6 | bubaque
# Processing Record 39 of Set 6 | port hardy
# Processing Record 40 of Set 6 | attawapiskat
# City not found. Skipping...
# Processing Record 41 of Set 6 | forio
# Processing Record 42 of Set 6 | coahuayana
# Processing Record 43 of Set 6 | bukama
# Processing Record 44 of Set 6 | kindu
# Processing Record 45 of Set 6 | winneba
# Processing Record 46 of Set 6 | eyl
# Processing Record 47 of Set 6 | hauterive
# Processing Record 48 of Set 6 | neiafu
# Processing Record 49 of Set 6 | lavumisa
# Processing Record 50 of Set 6 | phan thiet
# Processing Record 1 of Set 7 | alekseyevsk
# Processing Record 2 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 3 of Set 7 | yar-sale
# Processing Record 4 of Set 7 | mnogovershinnyy
# Processing Record 5 of Set 7 | krasnoselkup
# Processing Record 6 of Set 7 | umm ruwabah
# City not found. Skipping...
# Processing Record 7 of Set 7 | ormara
# Processing Record 8 of Set 7 | souillac
# Processing Record 9 of Set 7 | jashpurnagar
# Processing Record 10 of Set 7 | labuhan
# Processing Record 11 of Set 7 | of
# City not found. Skipping...
# Processing Record 12 of Set 7 | tambacounda
# Processing Record 13 of Set 7 | poya
# Processing Record 14 of Set 7 | coos bay
# Processing Record 15 of Set 7 | paamiut
# Processing Record 16 of Set 7 | lasem
# Processing Record 17 of Set 7 | pak phanang
# Processing Record 18 of Set 7 | najran
# Processing Record 19 of Set 7 | payo
# Processing Record 20 of Set 7 | tevaitoa
# Processing Record 21 of Set 7 | pisco
# Processing Record 22 of Set 7 | sinop
# Processing Record 23 of Set 7 | havre-saint-pierre
# Processing Record 24 of Set 7 | oksfjord
# Processing Record 25 of Set 7 | chara
# Processing Record 26 of Set 7 | the valley
# Processing Record 27 of Set 7 | joshimath
# Processing Record 28 of Set 7 | portoferraio
# Processing Record 29 of Set 7 | saint-fabien
# City not found. Skipping...
# Processing Record 30 of Set 7 | carutapera
# Processing Record 31 of Set 7 | cayenne
# Processing Record 32 of Set 7 | walvis bay
# Processing Record 33 of Set 7 | sikasso
# Processing Record 34 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 35 of Set 7 | muros
# Processing Record 36 of Set 7 | richards bay
# Processing Record 37 of Set 7 | urbano santos
# Processing Record 38 of Set 7 | dong hoi
# Processing Record 39 of Set 7 | atar
# Processing Record 40 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 41 of Set 7 | plouzane
# Processing Record 42 of Set 7 | boden
# Processing Record 43 of Set 7 | comodoro rivadavia
# Processing Record 44 of Set 7 | tupik
# Processing Record 45 of Set 7 | marsh harbour
# Processing Record 46 of Set 7 | butaritari
# Processing Record 47 of Set 7 | san cristobal
# Processing Record 48 of Set 7 | riyadh
# Processing Record 49 of Set 7 | severo-kurilsk
# Processing Record 50 of Set 7 | arlit
# Processing Record 1 of Set 8 | chernyshevskiy
# Processing Record 2 of Set 8 | santiago del estero
# Processing Record 3 of Set 8 | garowe
# Processing Record 4 of Set 8 | finschhafen
# Processing Record 5 of Set 8 | kaitangata
# Processing Record 6 of Set 8 | talcahuano
# Processing Record 7 of Set 8 | manadhoo
# Processing Record 8 of Set 8 | namibe
# Processing Record 9 of Set 8 | sibolga
# Processing Record 10 of Set 8 | pangody
# Processing Record 11 of Set 8 | qiongshan
# Processing Record 12 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 8 | puerto cabezas
# Processing Record 14 of Set 8 | armidale
# Processing Record 15 of Set 8 | alice springs
# Processing Record 16 of Set 8 | verkhoyansk
# Processing Record 17 of Set 8 | kysyl-syr
# Processing Record 18 of Set 8 | srivardhan
# Processing Record 19 of Set 8 | kayerkan
# Processing Record 20 of Set 8 | hithadhoo
# Processing Record 21 of Set 8 | palampur
# Processing Record 22 of Set 8 | alenquer
# Processing Record 23 of Set 8 | yarensk
# Processing Record 24 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 25 of Set 8 | kasama
# Processing Record 26 of Set 8 | masinigudi
# Processing Record 27 of Set 8 | aljezur
# Processing Record 28 of Set 8 | nanakuli
# Processing Record 29 of Set 8 | palmer
# Processing Record 30 of Set 8 | cuamba
# Processing Record 31 of Set 8 | dali
# Processing Record 32 of Set 8 | charyshskoye
# Processing Record 33 of Set 8 | birao
# Processing Record 34 of Set 8 | copiapo
# Processing Record 35 of Set 8 | shepsi
# Processing Record 36 of Set 8 | svetlyy
# Processing Record 37 of Set 8 | pandan
# Processing Record 38 of Set 8 | muravlenko
# Processing Record 39 of Set 8 | xining
# Processing Record 40 of Set 8 | mitu
# Processing Record 41 of Set 8 | maldonado
# Processing Record 42 of Set 8 | ilulissat
# Processing Record 43 of Set 8 | vestmanna
# Processing Record 44 of Set 8 | ulety
# Processing Record 45 of Set 8 | crissier
# Processing Record 46 of Set 8 | hurghada
# Processing Record 47 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 48 of Set 8 | touros
# Processing Record 49 of Set 8 | parabel
# Processing Record 50 of Set 8 | palomares
# Processing Record 1 of Set 9 | paita
# Processing Record 2 of Set 9 | bugene
# Processing Record 3 of Set 9 | gornyy
# Processing Record 4 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 5 of Set 9 | terney
# Processing Record 6 of Set 9 | samarinda
# Processing Record 7 of Set 9 | napasar
# Processing Record 8 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 9 of Set 9 | camacari
# Processing Record 10 of Set 9 | sitka
# Processing Record 11 of Set 9 | bontang
# Processing Record 12 of Set 9 | khandbari
# Processing Record 13 of Set 9 | abonnema
# Processing Record 14 of Set 9 | borogontsy
# Processing Record 15 of Set 9 | klyuchi
# Processing Record 16 of Set 9 | dubenskiy
# City not found. Skipping...
# Processing Record 17 of Set 9 | sangar
# Processing Record 18 of Set 9 | luena
# Processing Record 19 of Set 9 | camana
# Processing Record 20 of Set 9 | altea
# Processing Record 21 of Set 9 | kushmurun
# Processing Record 22 of Set 9 | adeje
# Processing Record 23 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 24 of Set 9 | patiya
# Processing Record 25 of Set 9 | gurgan
# City not found. Skipping...
# Processing Record 26 of Set 9 | okha
# Processing Record 27 of Set 9 | quang ngai
# Processing Record 28 of Set 9 | aktau
# Processing Record 29 of Set 9 | roebourne
# Processing Record 30 of Set 9 | puerto escondido
# Processing Record 31 of Set 9 | lahij
# Processing Record 32 of Set 9 | kununurra
# Processing Record 33 of Set 9 | mecca
# Processing Record 34 of Set 9 | osa
# Processing Record 35 of Set 9 | axim
# Processing Record 36 of Set 9 | olden
# Processing Record 37 of Set 9 | yulara
# Processing Record 38 of Set 9 | lata
# Processing Record 39 of Set 9 | burien
# Processing Record 40 of Set 9 | russell
# Processing Record 41 of Set 9 | fort abbas
# Processing Record 42 of Set 9 | belmonte
# Processing Record 43 of Set 9 | seydi
# Processing Record 44 of Set 9 | hobyo
# Processing Record 45 of Set 9 | sinnamary
# Processing Record 46 of Set 9 | kaniama
# Processing Record 47 of Set 9 | greve strand
# Processing Record 48 of Set 9 | arandis
# Processing Record 49 of Set 9 | saint-augustin
# Processing Record 50 of Set 9 | mbengwi
# Processing Record 1 of Set 10 | orlik
# Processing Record 2 of Set 10 | tibati
# Processing Record 3 of Set 10 | ippy
# Processing Record 4 of Set 10 | balykshi
# Processing Record 5 of Set 10 | shimoda
# Processing Record 6 of Set 10 | canutama
# Processing Record 7 of Set 10 | valle de angeles
# Processing Record 8 of Set 10 | liverpool
# Processing Record 9 of Set 10 | solnechnyy
# Processing Record 10 of Set 10 | tancanhuitz
# Processing Record 11 of Set 10 | henties bay
# Processing Record 12 of Set 10 | crib point
# Processing Record 13 of Set 10 | scalloway
# City not found. Skipping...
# Processing Record 14 of Set 10 | gayeri
# Processing Record 15 of Set 10 | hirara
# Processing Record 16 of Set 10 | balsas
# Processing Record 17 of Set 10 | gasa
# Processing Record 18 of Set 10 | mogochin
# City not found. Skipping...
# Processing Record 19 of Set 10 | santa rosa
# Processing Record 20 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 21 of Set 10 | diamantino
# Processing Record 22 of Set 10 | lephepe
# City not found. Skipping...
# Processing Record 23 of Set 10 | dengzhou
# Processing Record 24 of Set 10 | amboasary
# Processing Record 25 of Set 10 | itacare
# Processing Record 26 of Set 10 | uk
# City not found. Skipping...
# Processing Record 27 of Set 10 | skalistyy
# City not found. Skipping...
# Processing Record 28 of Set 10 | podyuga
# Processing Record 29 of Set 10 | willowmore
# Processing Record 30 of Set 10 | panzhihua
# Processing Record 31 of Set 10 | svetlogorsk
# Processing Record 32 of Set 10 | tyukhtet
# Processing Record 33 of Set 10 | sur
# Processing Record 34 of Set 10 | vedaranniyam
# City not found. Skipping...
# Processing Record 35 of Set 10 | san patricio
# Processing Record 36 of Set 10 | new castle
# Processing Record 37 of Set 10 | penzance
# Processing Record 38 of Set 10 | naryan-mar
# Processing Record 39 of Set 10 | kemijarvi
# Processing Record 40 of Set 10 | lazo
# Processing Record 41 of Set 10 | morada nova
# Processing Record 42 of Set 10 | iquique
# Processing Record 43 of Set 10 | krasnyy chikoy
# Processing Record 44 of Set 10 | leh
# Processing Record 45 of Set 10 | chapais
# Processing Record 46 of Set 10 | suntar
# Processing Record 47 of Set 10 | ngawi
# Processing Record 48 of Set 10 | turka
# Processing Record 49 of Set 10 | havoysund
# Processing Record 50 of Set 10 | westport
# Processing Record 1 of Set 11 | verkhnevilyuysk
# Processing Record 2 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 3 of Set 11 | coxim
# Processing Record 4 of Set 11 | lakes entrance
# Processing Record 5 of Set 11 | trapani
# Processing Record 6 of Set 11 | matamoros
# Processing Record 7 of Set 11 | uwayl
# City not found. Skipping...
# Processing Record 8 of Set 11 | zhigalovo
# Processing Record 9 of Set 11 | tautira
# Processing Record 10 of Set 11 | charters towers
# Processing Record 11 of Set 11 | kihei
# Processing Record 12 of Set 11 | rurrenabaque
# Processing Record 13 of Set 11 | viligili
# City not found. Skipping...
# Processing Record 14 of Set 11 | saint george
# Processing Record 15 of Set 11 | unity
# Processing Record 16 of Set 11 | katsuura
# Processing Record 17 of Set 11 | bukachacha
# Processing Record 18 of Set 11 | zhuhai
# Processing Record 19 of Set 11 | pilar
# Processing Record 20 of Set 11 | kiunga
# Processing Record 21 of Set 11 | monforte de lemos
# Processing Record 22 of Set 11 | homer
# Processing Record 23 of Set 11 | takoradi
# Processing Record 24 of Set 11 | camocim
# Processing Record 25 of Set 11 | dillon
# Processing Record 26 of Set 11 | luderitz
# Processing Record 27 of Set 11 | ruy barbosa
# Processing Record 28 of Set 11 | port-gentil
# Processing Record 29 of Set 11 | luancheng
# Processing Record 30 of Set 11 | middlebury
# Processing Record 31 of Set 11 | dakar
# Processing Record 32 of Set 11 | tiarei
# Processing Record 33 of Set 11 | necochea
# Processing Record 34 of Set 11 | kedgwick
# Processing Record 35 of Set 11 | boende
# Processing Record 36 of Set 11 | gamba
# Processing Record 37 of Set 11 | serik
# Processing Record 38 of Set 11 | marawi
# Processing Record 39 of Set 11 | urumqi
# Processing Record 40 of Set 11 | bonavista
# Processing Record 41 of Set 11 | saldanha
# Processing Record 42 of Set 11 | opuwo
# Processing Record 43 of Set 11 | mahon
# Processing Record 44 of Set 11 | abu dhabi
# Processing Record 45 of Set 11 | mwense
# Processing Record 46 of Set 11 | tezu
# Processing Record 47 of Set 11 | port hedland
# Processing Record 48 of Set 11 | sakakah
# Processing Record 49 of Set 11 | tolmachevo
# Processing Record 50 of Set 11 | port hawkesbury
# Processing Record 1 of Set 12 | padang
# Processing Record 2 of Set 12 | valley city
# Processing Record 3 of Set 12 | nioro
# Processing Record 4 of Set 12 | uglich
# Processing Record 5 of Set 12 | hambantota
# Processing Record 6 of Set 12 | nelidovo
# Processing Record 7 of Set 12 | turukhansk
# Processing Record 8 of Set 12 | westminster
# Processing Record 9 of Set 12 | serra talhada
# Processing Record 10 of Set 12 | zhuji
# Processing Record 11 of Set 12 | cabo san lucas
# Processing Record 12 of Set 12 | jalu
# Processing Record 13 of Set 12 | constitucion
# Processing Record 14 of Set 12 | amuntai
# Processing Record 15 of Set 12 | maniitsoq
# Processing Record 16 of Set 12 | zhaotong
# Processing Record 17 of Set 12 | andenes
# Processing Record 18 of Set 12 | pimentel
# Processing Record 19 of Set 12 | angoche
# Processing Record 20 of Set 12 | pasighat
# Processing Record 21 of Set 12 | datong
# Processing Record 22 of Set 12 | isfana
# Processing Record 23 of Set 12 | blackfoot
# Processing Record 24 of Set 12 | te anau
# Processing Record 25 of Set 12 | pevek
# Processing Record 26 of Set 12 | ucluelet
# Processing Record 27 of Set 12 | puerto leguizamo
# Processing Record 28 of Set 12 | sitrah
# Processing Record 29 of Set 12 | ambanja
# Processing Record 30 of Set 12 | mutare
# Processing Record 31 of Set 12 | winnipeg
# Processing Record 32 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 33 of Set 12 | winburg
# Processing Record 34 of Set 12 | pacific grove
# Processing Record 35 of Set 12 | jurbarkas
# Processing Record 36 of Set 12 | matara
# Processing Record 37 of Set 12 | mercedes
# Processing Record 38 of Set 12 | khuzhir
# Processing Record 39 of Set 12 | taburi
# City not found. Skipping...
# Processing Record 40 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 41 of Set 12 | okhotsk
# Processing Record 42 of Set 12 | sarlat-la-caneda
# Processing Record 43 of Set 12 | novomykolayivka
# Processing Record 44 of Set 12 | riviere-au-renard
# Processing Record 45 of Set 12 | chokwe
# Processing Record 46 of Set 12 | new ulm
# Processing Record 47 of Set 12 | havelock
# Processing Record 48 of Set 12 | kaolack
# Processing Record 49 of Set 12 | churachandpur
# Processing Record 50 of Set 12 | san juan
# Processing Record 1 of Set 13 | ihosy
# Processing Record 2 of Set 13 | benemerito de las americas
# Processing Record 3 of Set 13 | porto seguro
# Processing Record 4 of Set 13 | baherden
# Processing Record 5 of Set 13 | valparaiso
# Processing Record 6 of Set 13 | sungaipenuh
# Processing Record 7 of Set 13 | sao sebastiao
# Processing Record 8 of Set 13 | polson
# Processing Record 9 of Set 13 | santa luzia
# Processing Record 10 of Set 13 | islamkot
# Processing Record 11 of Set 13 | abbeville
# Processing Record 12 of Set 13 | guanare
# Processing Record 13 of Set 13 | prince rupert
# Processing Record 14 of Set 13 | blonduos
# City not found. Skipping...
# Processing Record 15 of Set 13 | washington
# Processing Record 16 of Set 13 | nemuro
# Processing Record 17 of Set 13 | viedma
# Processing Record 18 of Set 13 | neryungri
# Processing Record 19 of Set 13 | port pirie
# Processing Record 20 of Set 13 | honiara
# Processing Record 21 of Set 13 | vicuna
# Processing Record 22 of Set 13 | gulu
# Processing Record 23 of Set 13 | egvekinot
# Processing Record 24 of Set 13 | paducah
# Processing Record 25 of Set 13 | halifax
# Processing Record 26 of Set 13 | iracoubo
# Processing Record 27 of Set 13 | khani
# Processing Record 28 of Set 13 | jiexiu
# Processing Record 29 of Set 13 | wau
# Processing Record 30 of Set 13 | rakitnoye
# Processing Record 31 of Set 13 | wagar
# Processing Record 32 of Set 13 | doha
# Processing Record 33 of Set 13 | saint anthony
# Processing Record 34 of Set 13 | liaocheng
# Processing Record 35 of Set 13 | vrangel
# Processing Record 36 of Set 13 | campos
# Processing Record 37 of Set 13 | bloemfontein
# Processing Record 38 of Set 13 | college
# Processing Record 39 of Set 13 | puerto narino
# Processing Record 40 of Set 13 | nome
# Processing Record 41 of Set 13 | nsanje
# Processing Record 42 of Set 13 | celestun
# Processing Record 43 of Set 13 | rio grande
# Processing Record 44 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 13 | karlstad
# Processing Record 46 of Set 13 | zyryanskoye
# Processing Record 47 of Set 13 | thinadhoo
# Processing Record 48 of Set 13 | hilton head island
# Processing Record 49 of Set 13 | alanya
# Processing Record 50 of Set 13 | fort nelson
# Processing Record 1 of Set 14 | abrau-dyurso
# Processing Record 2 of Set 14 | tilichiki
# Processing Record 3 of Set 14 | yaan
# Processing Record 4 of Set 14 | ponta delgada
# Processing Record 5 of Set 14 | preobrazheniye
# Processing Record 6 of Set 14 | tiberias
# Processing Record 7 of Set 14 | ankara
# Processing Record 8 of Set 14 | kollam
# Processing Record 9 of Set 14 | minab
# Processing Record 10 of Set 14 | wairoa
# Processing Record 11 of Set 14 | yishui
# Processing Record 12 of Set 14 | yumen
# Processing Record 13 of Set 14 | davila
# Processing Record 14 of Set 14 | el nispero
# Processing Record 15 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 16 of Set 14 | morondava
# Processing Record 17 of Set 14 | mareeba
# Processing Record 18 of Set 14 | hemsedal
# Processing Record 19 of Set 14 | dawlatabad
# Processing Record 20 of Set 14 | qingan
# City not found. Skipping...
# Processing Record 21 of Set 14 | bodden town
# Processing Record 22 of Set 14 | trinidad
# Processing Record 23 of Set 14 | kabalo
# Processing Record 24 of Set 14 | yining
# Processing Record 25 of Set 14 | chicama
# Processing Record 26 of Set 14 | sayyan
# Processing Record 27 of Set 14 | moerai
# Processing Record 28 of Set 14 | omboue
# Processing Record 29 of Set 14 | beringovskiy
# Processing Record 30 of Set 14 | trincomalee
# Processing Record 31 of Set 14 | sovetskiy
# Processing Record 32 of Set 14 | miandoab
# Processing Record 33 of Set 14 | alofi
# Processing Record 34 of Set 14 | pochutla
# Processing Record 35 of Set 14 | berea
# Processing Record 36 of Set 14 | fomboni
# Processing Record 37 of Set 14 | tromso
# Processing Record 38 of Set 14 | do gonbadan
# Processing Record 39 of Set 14 | methoni
# Processing Record 40 of Set 14 | madimba
# Processing Record 41 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 14 | tucuman
# Processing Record 43 of Set 14 | kharian
# Processing Record 44 of Set 14 | trairi
# Processing Record 45 of Set 14 | athabasca
# Processing Record 46 of Set 14 | dalhousie
# Processing Record 47 of Set 14 | zapolyarnyy
# Processing Record 48 of Set 14 | emba
# Processing Record 49 of Set 14 | togur
# Processing Record 50 of Set 14 | sijunjung
# Processing Record 1 of Set 15 | brownsville
# Processing Record 2 of Set 15 | ushibuka
# Processing Record 3 of Set 15 | buenaventura
# Processing Record 4 of Set 15 | igrim
# Processing Record 5 of Set 15 | ovsyanka
# Processing Record 6 of Set 15 | barguzin
# Processing Record 7 of Set 15 | faanui
# Processing Record 8 of Set 15 | fez
# Processing Record 9 of Set 15 | macas
# Processing Record 10 of Set 15 | satipo
# Processing Record 11 of Set 15 | antofagasta
# Processing Record 12 of Set 15 | bongandanga
# Processing Record 13 of Set 15 | brae
# Processing Record 14 of Set 15 | algiers
# Processing Record 15 of Set 15 | izumo
# Processing Record 16 of Set 15 | arazede
# Processing Record 17 of Set 15 | aransas pass
# Processing Record 18 of Set 15 | hofn
# Processing Record 19 of Set 15 | razole
# Processing Record 20 of Set 15 | mao
# Processing Record 21 of Set 15 | sao joao da barra
# Processing Record 22 of Set 15 | ozgon
# City not found. Skipping...
# Processing Record 23 of Set 15 | laurel
# Processing Record 24 of Set 15 | san matias
# Processing Record 25 of Set 15 | jiayuguan
# Processing Record 26 of Set 15 | salta
# Processing Record 27 of Set 15 | eldorado
# Processing Record 28 of Set 15 | kushima
# Processing Record 29 of Set 15 | kargasok
# Processing Record 30 of Set 15 | butembo
# Processing Record 31 of Set 15 | mitchell
# Processing Record 32 of Set 15 | filimonovo
# Processing Record 33 of Set 15 | belyy yar
# Processing Record 34 of Set 15 | banyuwangi
# Processing Record 35 of Set 15 | ochamchira
# Processing Record 36 of Set 15 | tessalit
# Processing Record 37 of Set 15 | saint-marc
# Processing Record 38 of Set 15 | haines junction
# Processing Record 39 of Set 15 | ambon
# Processing Record 40 of Set 15 | maneadero
# Processing Record 41 of Set 15 | rawson
# Processing Record 42 of Set 15 | ponnani
# Processing Record 43 of Set 15 | pouebo
# Processing Record 44 of Set 15 | makakilo city
# Processing Record 45 of Set 15 | kaeo
# Processing Record 46 of Set 15 | marzuq
# Processing Record 47 of Set 15 | xichang
# Processing Record 48 of Set 15 | morgan city
# Processing Record 49 of Set 15 | byron bay
# Processing Record 50 of Set 15 | prenzlau
# Processing Record 1 of Set 16 | gejiu
# Processing Record 2 of Set 16 | teahupoo
# Processing Record 3 of Set 16 | burns lake
# Processing Record 4 of Set 16 | fukue
# Processing Record 5 of Set 16 | batagay-alyta
# Processing Record 6 of Set 16 | melfi
# Processing Record 7 of Set 16 | bathsheba
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#7. Add the data to a new DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Powell      US  40.1578  -83.0752     51.01        50           1
# 1    Ayotzintepec      MX  17.6667  -96.1333     81.32        56          87
# 2      Bredasdorp      ZA -34.5322   20.0403     57.20        94          96
# 3           Bluff      NZ -46.6000  168.3333     60.01        76          84
# 4  Saint-Philippe      RE -21.3585   55.7679     75.20        78           0
# 5            Hami      CN  42.8000   93.4500     56.64        11           1
# 6           Lagoa      PT  39.0500  -27.9833     60.55        88          48
# 7       Esperance      AU -33.8667  121.9000     66.20        68          75
# 8      Champerico      GT  14.3000  -91.9167     68.00        96         100
# 9          Beloha      MG -25.1667   45.0500     69.60        96          13
#
#    Wind Speed Current Description
# 0       10.36           clear sky
# 1        2.80     overcast clouds
# 2        3.40     overcast clouds
# 3        7.00       broken clouds
# 4        6.91          light rain
# 5       11.01           clear sky
# 6       11.27    scattered clouds
# 7       13.80       broken clouds
# 8        6.98     overcast clouds
# 9        2.98          few clouds

# %%
#8 Export the DataFrame as a CSV file, and save it as WeatherPy_Database.csv in the Weather_Database folder.
output_data_file = "Weather_Database/WeatherPy_Database.csv"
city_data_df.to_csv(output_data_file, index=False)
